# %%
# !pip install flask-ngrok
# !pip install flask==0.12.2 
# !pip install pyngrok==4.1.1
# !ngrok authtoken '28hAArvvn7CjTsQWXSG1Cx3Bz4S_5rDs4HPnpMv441LtoxnGg'
# Out:
# ...
#      |████████████████████████████████| 83 kB 1.5 MB/s
# ...
#   Attempting uninstall: flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-py3-none-any.whl size=15983 sha256=20a871ed2d9ba72afad89b7d56e5128a43990da6ed6708ddc7f91ad60fcdbb12
#   Stored in directory: /root/.cache/pip/wheels/b1/d9/12/045a042fee3127dc40ba6f5df2798aa2df38c414bf533ca765
# Successfully built pyngrok
# ...
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !git clone https://github.com/tanmai-h/minor-project.git
# Out:
# Cloning into 'minor-project'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 51 (delta 17), reused 47 (delta 13), pack-reused 0
# Unpacking objects: 100% (51/51), done.

# %%
# !pip install keras_applications
# Out:
# ...
#      |████████████████████████████████| 50 kB 5.7 MB/s
# ...

# %%
# %cd minor-project
# Out:
# /content/minor-project

# %%
from model_new import VizGradCAM
# Out:
# Sanity
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 240, 240, 3  0           []
#                                 )]
#
#  rescaling_4 (Rescaling)        (None, 240, 240, 3)  0           ['input_5[0][0]']
#
#  normalization_4 (Normalization  (None, 240, 240, 3)  7          ['rescaling_4[0][0]']
#  )
#
#  stem_conv_pad (ZeroPadding2D)  (None, 241, 241, 3)  0           ['normalization_4[0][0]']
#
#  stem_conv (Conv2D)             (None, 120, 120, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 120, 120, 32  128         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 120, 120, 32  0           ['stem_bn[0][0]']
#                                 )
#
# ...

# %%
test_img = cv2.imread("/content/test_image.jpeg")
fig,pred = VizGradCAM(test_img, plot_results=True)

# %%
# !python model_new.py

# %%
# !python app.py
# Out:
# Streaming output truncated to the last 5000 lines.
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 15, 15, 672)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 15, 15, 112)  75264       ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 15, 15, 112)  448        ['block5b_project_conv[0][0]']
#  lization)
#
#  block5b_drop (Dropout)         (None, 15, 15, 112)  0           ['block5b_project_bn[0][0]']
#
#  block5b_add (Add)              (None, 15, 15, 112)  0           ['block5b_drop[0][0]',
#                                                                   'block5a_project_bn[0][0]']
#
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !zip -r minor-project-new.zip minor-project
# Out:
#   adding: minor-project/ (stored 0%)
#   adding: minor-project/chest.png (deflated 0%)
#   adding: minor-project/pre.png (deflated 4%)
#   adding: minor-project/templates/ (stored 0%)
#   adding: minor-project/templates/result.html (deflated 64%)
#   adding: minor-project/templates/index.html (deflated 55%)
#   adding: minor-project/load_data.py (deflated 58%)
#   adding: minor-project/__pycache__/ (stored 0%)
#   adding: minor-project/__pycache__/model_gradcam.cpython-37.pyc (deflated 38%)
#   adding: minor-project/__pycache__/model_new.cpython-37.pyc (deflated 41%)
#   adding: minor-project/__pycache__/load_data.cpython-37.pyc (deflated 40%)
#   adding: minor-project/NASNET.py (deflated 76%)
#   adding: minor-project/static/ (stored 0%)
#   adding: minor-project/static/css/ (stored 0%)
#   adding: minor-project/static/css/semantic.min.css (deflated 84%)
#   adding: minor-project/static/css/semantic.css (deflated 85%)
#   adding: minor-project/static/uploads/ (stored 0%)
# ...
